# %%
### Library Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

### Script Imports
import utils


### Import the loans file
df = pd.read_csv('../../project/banking_data/account.csv', sep=';')
# Out:
#       account_id  district_id                   frequency    date
# 0            576           55            monthly issuance  930101
# 1           3818           74            monthly issuance  930101
# 2            704           55            monthly issuance  930101
# 3           2378           16            monthly issuance  930101
# 4           2632           24            monthly issuance  930102
# 5           1972           77            monthly issuance  930102
# 6           1539            1  issuance after transaction  930103
# 7            793           47            monthly issuance  930103
# 8           2484           74            monthly issuance  930103
# 9           1695           76            monthly issuance  930103
# 10          1726           48            monthly issuance  930103
# 11          2881           70            monthly issuance  930104
# 12          2357           19            monthly issuance  930104
# ...

# %%
accounts = utils.date_conversion(df,'date')
accounts
# Out:
#       account_id  district_id                   frequency        date
# 0            576           55            monthly issuance  01-01-1993
# 1           3818           74            monthly issuance  01-01-1993
# 2            704           55            monthly issuance  01-01-1993
# 3           2378           16            monthly issuance  01-01-1993
# 4           2632           24            monthly issuance  02-01-1993
# 5           1972           77            monthly issuance  02-01-1993
# 6           1539            1  issuance after transaction  03-01-1993
# 7            793           47            monthly issuance  03-01-1993
# 8           2484           74            monthly issuance  03-01-1993
# 9           1695           76            monthly issuance  03-01-1993
# 10          1726           48            monthly issuance  03-01-1993
# 11          2881           70            monthly issuance  04-01-1993
# ...
